# %%
import urllib.request as url
import cv2
import numpy as np

# %%
men_file = open('men.txt')
#women_file = open('women.txt')

# %%
men_urls = men_file.readlines()

# %%
men_urls[0]
# Out:
# 'https://2x1dks3q6aoj44bz1r1tr92f-wpengine.netdna-ssl.com/wp-content/uploads/2017/07/A-Man-With-Bardholz-Full-Beard-July-2017.jpg\n'

# %%
men_urls[4]
# Out:
# 'https://wwwimage-secure.cbsstatic.com/thumbnails/photos/w1920/marquee/1025957/72e1f4c7b764c8d2_mwp_hp_hero_landscape.jpg\n'

# %%
img_path = url.urlretrieve(men_urls[0], 'img_1.jpg')[0]

# %%
img_path
# Out:
# 'img_1.jpg'

# %%
img = cv2.imread(img_path)

# %%
img[0]
# Out:
# array([[ 77, 111, 100],
#        [ 79, 113, 102],
#        [ 82, 116, 105],
#        ...,
#        [ 71, 121, 109],
#        [ 65, 115, 103],
#        [ 55, 105,  93]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
img = cv2.resize(img,None,fx=0.5, fy=0.5)
while True:
    cv2.imshow('result',img)
    # 27 - ASCII of Escape
    if cv2.waitKey(2) == 27:
        break
cv2.destroyAllWindows()
