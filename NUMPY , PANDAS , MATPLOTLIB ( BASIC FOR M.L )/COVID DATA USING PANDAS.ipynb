# %%
import pandas as pd

# %%
df = pd.read_csv('covid_19_data.csv')

# %%
df.shape
# Out:
# (236017, 8)

# %%
df.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
df.tail()
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 236012  236013      02/27/2021  Zaporizhia Oblast         Ukraine
# 236013  236014      02/27/2021            Zeeland     Netherlands
# 236014  236015      02/27/2021           Zhejiang  Mainland China
# 236015  236016      02/27/2021    Zhytomyr Oblast         Ukraine
# 236016  236017      02/27/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 236012  2021-02-28 05:22:20    69504.0  1132.0    65049.0
# 236013  2021-02-28 05:22:20    16480.0   178.0        0.0
# 236014  2021-02-28 05:22:20     1321.0     1.0     1314.0
# 236015  2021-02-28 05:22:20    50582.0   834.0    44309.0
# 236016  2021-02-28 05:22:20   255335.0  3732.0        0.0

# %%
len(pd.unique(df['Country/Region']))
# Out:
# 227

# %%
pd.value_counts(df['Country/Region'])
# Out:
# Russia                 22698
# US                     21462
# Japan                  13600
# Mainland China         12500
# India                   9815
#                        ...
# ('St. Martin',)            1
# Cape Verde                 1
# Republic of Ireland        1
#  Azerbaijan                1
# St. Martin                 1
# Name: Country/Region, Length: 227, dtype: int64

# %%
df[df['Deaths'] >  100000]
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 221818  221819      02/09/2021        England             UK
# 222581  222582      02/10/2021        England             UK
# 223344  223345      02/11/2021        England             UK
# 224107  224108      02/12/2021        England             UK
# 224870  224871      02/13/2021        England             UK
# 225633  225634      02/14/2021        England             UK
# 226396  226397      02/15/2021        England             UK
# 227159  227160      02/16/2021        England             UK
# 227922  227923      02/17/2021        England             UK
# 228685  228686      02/18/2021        England             UK
# 229448  229449      02/19/2021        England             UK
# 230212  230213      02/20/2021        England             UK
# 230976  230977      02/21/2021        England             UK
# 231740  231741      02/22/2021        England             UK
# ...

# %%
df[df['Deaths'] >  100000].head()
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 221818  221819      02/09/2021        England             UK
# 222581  222582      02/10/2021        England             UK
# 223344  223345      02/11/2021        England             UK
# 224107  224108      02/12/2021        England             UK
# 224870  224871      02/13/2021        England             UK
#
#                 Last Update  Confirmed    Deaths  Recovered
# 221818  2021-02-10 05:22:41  3480147.0  100385.0        0.0
# 222581  2021-02-11 05:23:55  3491698.0  101311.0        0.0
# 223344  2021-02-12 05:23:29  3503699.0  101905.0        0.0
# 224107  2021-02-13 05:22:12  3516998.0  102562.0        0.0
# 224870  2021-02-14 05:23:43  3528695.0  103106.0        0.0

# %%
df[df['Deaths'] >  100000].shape
# Out:
# (19, 8)

# %%
df['Deaths'].max()
# Out:
# 108208.0

# %%
df['Deaths'].argmax()
# Out:
# 235560

# %%
df[df['Deaths'] >  100000]['Country/Region']
# Out:
# 221818    UK
# 222581    UK
# 223344    UK
# 224107    UK
# 224870    UK
# 225633    UK
# 226396    UK
# 227159    UK
# 227922    UK
# 228685    UK
# 229448    UK
# 230212    UK
# 230976    UK
# 231740    UK
# 232504    UK
# 233268    UK
# 234032    UK
# 234796    UK
# 235560    UK
# Name: Country/Region, dtype: object

# %%
df[df['Deaths'] >  50000]['Country/Region'].unique()
# Out:
# array(['France', 'UK', 'Iran', 'India', 'Brazil', 'Argentina', 'US'],
#       dtype=object)

# %%
ind_df = df[df['Country/Region'] == 'India']

# %%
ind_df.shape
# Out:
# (9815, 8)

# %%
ind_df.max()
# Out:
# SNo                     235995
# ObservationDate     12/31/2020
# Country/Region           India
# Last Update        4/6/20 9:37
# Confirmed            2146777.0
# Deaths                 52092.0
# Recovered            2020951.0
# dtype: object

# %%
ind_df['Deaths'].max()
# Out:
# 52092.0

# %%
df.groupby('Country/Region').sum('Deaths')
# Out:
#                                      SNo   Confirmed    Deaths   Recovered
# Country/Region
#  Azerbaijan                         2664         1.0       0.0         0.0
# ('St. Martin',)                     4675         2.0       0.0         0.0
# Afghanistan                     37614761  11651049.0  434582.0   8710952.0
# Albania                         37571690   8319315.0  170096.0   4803229.0
# Algeria                         37612070  16779265.0  544860.0  11373181.0
# ...                                  ...         ...       ...         ...
# West Bank and Gaza              37520235  17976110.0  178892.0  15226678.0
# Yemen                           37352574    506009.0  144616.0    303050.0
# Zambia                          37582345   5391390.0   95367.0   4771166.0
# Zimbabwe                        37569033   3071659.0   96985.0   2404400.0
# occupied Palestinian territory     38803        25.0       0.0         0.0
#
# [227 rows x 4 columns]

# %%
df.groupby('Country/Region').sum('Deaths').sort_values('Deaths',ascending = False).head()
# Out:
#                        SNo     Confirmed      Deaths     Recovered
# Country/Region
# US              2190017822  3.201291e+09  72223040.0  5.033710e+08
# Brazil           990718125  1.417935e+09  40013970.0  1.223330e+09
# India           1329199205  1.705856e+09  26087127.0  1.553543e+09
# Mexico          1194396779  2.532551e+08  24061279.0  1.973491e+08
# UK               595195427  3.854992e+08  17619785.0  1.082499e+06

# %%
df.groupby('Country/Region').mean('Deaths').sort_values('Deaths',ascending = False).head()
# Out:
#                           SNo      Confirmed        Deaths      Recovered
# Country/Region
# Iran            100390.317333  533357.376000  25526.266667  431142.056000
# Argentina       103853.486188  713467.765193  18151.099448  606001.687845
# South Africa    104543.886111  564540.827778  14975.063889  484907.558333
# Indonesia       103636.319559  334202.146006  10592.468320  266729.672176
# Turkey          106263.435028  717519.155367   9998.511299  642672.878531
